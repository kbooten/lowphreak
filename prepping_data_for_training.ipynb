# %% [markdown]
# # Getting Sentences to Vectorize
#
# I'm creating my own `word2vec` model, so I need tokenized sentences. Here I'm using a large chunk of the Project Gutenberg corpus as well as some [Amazon review data](https://snap.stanford.edu/data/web-Amazon.html).
#
# I attach the part-of-speech tag to the token so that I can disambiguate different word senses after training.
#
# *This notebook is repurposed from this one [here](https://github.com/kbooten/stylevise/blob/master/getting_syntax_ngrams.ipynb).*
# ***

# %%
import os
gb_files = [f for f in os.listdir("/Users/kyle/Documents/downloading_gutenberg/data/") if f.startswith('gb_')]

# %%
len(gb_files)
# Out:
# 19507

# %%
from tqdm import tqdm
import json

# %%
import spacy
nlp = spacy.load("en")

# %% [markdown]
# ### Gutenberg data

# %%
from collections import defaultdict

# %%
tokenized_sentences = []
from gutenberg.cleanup import strip_headers
#used_ids = []
#token2pos_tag_counts = defaultdict(lambda: defaultdict(int))

for fy in tqdm(gb_files): ## for debugging
#for fy in tqdm(gb_files):
    with open("/Users/kyle/Documents/downloading_gutenberg/data/"+fy,'r') as f:
        tempdata = f.read()
        filenumber = fy.lstrip("gb_").rstrip(".txt")
        if "Language: English" in tempdata[:1000]:  ## make sure english 
            tempdata = strip_headers(tempdata)
            tempspacy = nlp(tempdata[:100000])### limit to first n chars
            sents = list(tempspacy.sents)
            sents_ok = [sent for sent in sents if (sent.text[0] in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ' and sent.text[-1] in ".?!")]
            for sent in sents_ok:
                tagged = [(i.text.lower(),i.tag_) for i in sent]
                tagged_clean = [(token,tag) for token,tag in tagged if "\n" not in token]
                tokens = [token+"_"+tag for token,tag in tagged_clean]
                tokenized_sentences.append(tokens)
#                 for token,tag in tagged_clean:
#                     token2pos_tag_counts[token][tag]+=1
            ###
            #used_ids.append(filenumber)
# Out:
# 100%|██████████| 19507/19507 [11:31:57<00:00,  2.13s/it]

# %%
len(tokenized_sentences)
# Out:
# 4850043

# %%
tokenized_sentences[:100]
# Out:
# [['mr_NNP', '._.'],
#  ['in_IN',
#   'which_WDT',
#   'keziah_NNP',
#   'hears_VBZ',
#   'two_CD',
#   'proposals_NNS',
#   'and_CC',
#   'the_DT',
#   'beginning_NN',
#   'of_IN',
#   'a_DT',
#   'third_NNP',
#   'trumet_NNP',
#   'in_IN',
#   'a_DT',
#   'fog_NN',
#   ';_:',
#   'a_DT',
#   'fog_NN',
#   'blown_VBN',
#   'in_RB',
#   'during_IN',
#   'the_DT',
#   'night_NN',
#   'by_IN',
#   'the_DT',
#   'wind_NN',
#   'from_IN',
#   'the_DT',
#   'wide_JJ',
#   'atlantic_NNP',
#   '._.'],
#  ['the_DT',
#   'pole_NN',
#   'on_IN',
#   'cannon_NNP',
#   'hill_NNP',
#   ',_,',
#   'where_WRB',
#   'the_DT',
#   'beacon_NN',
#   'was_VBD',
#   'hoisted_VBN',
#   'when_WRB',
#   'the_DT',
#   'packet_NN',
#   'from_IN',
#   'boston_NNP',
#   'dropped_VBD',
#   'anchor_NN',
#   'in_IN',
#   'the_DT',
#   'bay_NN',
#   ',_,',
#   'was_VBD',
#   'shiny_JJ',
#   'and_CC',
#   'slippery_JJ',
#   '._.'],
#  ['the_DT',
#   'new_JJ',
#   'weathervane_NN',
#   ',_,',
#   'a_DT',
#   'gilded_VBN',
#   'whale_NN',
#   ',_,',
#   'presented_VBN',
#   'to_IN',
#   'the_DT',
#   '"_``',
#   'regular_JJ',
#   '"_\'\'',
#   'church_NN',
#   'by_IN',
#   'captain_NNP',
#   'zebedee_NNP',
#   'mayo_NNP',
#   ',_,',
#   'retired_VBN',
#   'whaler_NNP',
#   ',_,',
#   'swam_NNP',
#   'in_IN',
#   'a_DT',
#   'sea_NN',
#   'of_IN',
#   'cloud_NN',
#   '._.'],
#  ['the_DT',
#   'lichened_VBN',
#   'eaves_NNS',
#   'of_IN',
#   'the_DT',
#   'little_JJ',
#   '"_``',
#   'come_VB',
#   '-_HYPH',
#   'outer_NNP',
#   '"_\'\'',
#   'chapel_NN',
#   'dripped_VBD',
#   'at_IN',
#   'sedate_JJ',
#   'intervals_NNS',
#   '._.'],
#  ['the_DT',
#   'brick_NN',
#   'walk_VBP',
#   'leading_VBG',
#   'to_IN',
#   'the_DT',
#   'door_NN',
#   'of_IN',
#   'captain_NNP',
#   'elkanah_NNP',
#   'daniels_NNP',
#   "'s_POS",
#   'fine_JJ',
#   'residence_NN',
#   'held_VBD',
#   'undignified_JJ',
#   'puddles_NNS',
#   'in_IN',
#   'its_PRP$',
#   'hollows_NNS',
#   '._.'],
#  ['directly_RB',
#   'opposite_JJ',
#   'captain_NNP',
#   'elkanah_NNP',
#   "'s_POS",
#   'front_JJ',
#   'gate_NN',
#   ',_,',
#   'on_IN',
#   'the_DT',
#   'other_JJ',
#   'side_NN',
#   'of_IN',
#   'the_DT',
#   'main_JJ',
#   'road_NN',
#   ',_,',
#   'stood_VBD',
#   'the_DT',
#   'little_JJ',
#   'story_NN',
#   '-_HYPH',
#   'and_CC',
#   '-_HYPH',
#   'a_DT',
#   '-_HYPH',
#   'half_NN',
#   'house_NN',
#   ',_,',
#   'also_RB',
#   'the_DT',
#   'captain_NN',
#   "'s_POS",
#   'property_NN',
#   ',_,',
#   'which_WDT',
#   'for_IN',
#   'fourteen_CD',
#   'years_NNS',
#   'had_VBD',
#   'been_VBN',
#   'tenanted_VBN',
#   'by_IN',
#   'mrs._NNP',
#   'keziah_NNP',
#   'coffin_NNP',
#   'and_CC',
#   'her_PRP$',
#   'brother_NN',
#   ',_,',
#   'solomon_NNP',
#   'hall_NNP',
#   ',_,',
#   'the_DT',
#   'shoemaker_NN',
#   '._.'],
#  ['but_CC',
#   'solomon_NNP',
#   'had_VBD',
#   ',_,',
#   'the_DT',
#   'month_NN',
#   'before_RB',
#   ',_,',
#   'given_VBN',
#   'up_RP',
#   'his_PRP$',
#   'fight_NN',
#   'with_IN',
#   'debt_NN',
#   'and_CC',
#   'illness_NN',
#   'and_CC',
#   'was_VBD',
#   'sleeping_VBG',
#   'quietly_RB',
#   'in_IN',
#   'trumet_NNP',
#   "'s_POS",
#   'most_RBS',
#   'populous_JJ',
#   'center_NN',
#   ',_,',
#   'the_DT',
#   'graveyard_NN',
#   '._.'],
#  ['and_CC',
#   'keziah_NNP',
#   ',_,',
#   'left_VBD',
#   'alone_RB',
#   ',_,',
#   'had_VBD',
#   'decided_VBN',
#   'that_IN',
#   'the_DT',
#   'rent_NN',
#   'and_CC',
#   'living_NN',
#   'expenses_NNS',
#   'were_VBD',
#   'more_JJR',
#   'than_IN',
#   'her_PRP$',
#   'precarious_JJ',
#   'earnings_NNS',
#   'as_IN',
#   'a_DT',
#   'seamstress_NN',
#   'would_MD',
#   'warrant_VB',
#   ',_,',
#   'and_CC',
#   ',_,',
#   'having_VBG',
#   'bargained_VBN',
#   'with_IN',
#   'the_DT',
#   'furniture_NN',
#   'dealer_NN',
#   'in_IN',
#   'wellmouth_NNP',
#   'for_IN',
#   'the_DT',
#   'sale_NN',
#   'of_IN',
#   'her_PRP$',
#   'household_NN',
#   'effects_NNS',
#   ',_,',
#   'was_VBD',
#   'now_RB',
#   'busy_JJ',
#   'getting_VBG',
#   'them_PRP',
#   'ready_JJ',
#   'for_IN',
#   'the_DT',
#   'morrow_NN',
#   ',_,',
#   'when_WRB',
#   'the_DT',
#   'dealer_NN',
#   "'s_POS",
#   'wagon_NN',
#   'was_VBD',
#   'to_TO',
#   'call_VB',
#   '._.'],
#  ['the_DT',
#   'fog_NN',
#   'hung_VBD',
#   'like_IN',
#   'a_DT',
#   'wet_JJ',
#   'blanket_NN',
#   'over_IN',
#   'the_DT',
#   'house_NN',
#   'and_CC',
#   'its_PRP$',
#   'small_JJ',
#   'yard_NN',
#   ',_,',
#   'where_WRB',
#   'a_DT',
#   'few_JJ',
#   'venerable_JJ',
#   'pear_NN',
#   'trees_NNS',
#   ',_,',
#   'too_RB',
#   'conservative_JJ',
#   'in_IN',
#   'their_PRP$',
#   'old_JJ',
#   'age_NN',
#   'to_TO',
#   'venture_VB',
#   'a_DT',
#   'bud_NN',
#   'even_RB',
#   'though_IN',
#   'it_PRP',
#   'was_VBD',
#   'almost_RB',
#   'may_NNP',
#   ',_,',
#   'stood_VBD',
#   'bare_JJ',
#   'and_CC',
#   'forlorn_JJ',
#   '._.'],
#  ['the_DT', 'day_NN', 'was_VBD', 'dismal_JJ', '._.'],
#  ['the_DT',
#   'dismantled_JJ',
#   'dining_NN',
#   'room_NN',
#   ',_,',
#   'its_PRP$',
#   'tables_NNS',
#   'and_CC',
#   'chairs_NNS',
#   'pushed_VBD',
#   'into_IN',
#   'a_DT',
#   'corner_NN',
#   ',_,',
#   'and_CC',
#   'its_PRP$',
#   'faded_JJ',
#   'ingrain_NN',
#   'carpet_NN',
#   'partially_RB',
#   'stripped_VBN',
#   'from_IN',
#   'the_DT',
#   'floor_NN',
#   ',_,',
#   'was_VBD',
#   'dismal_JJ',
#   ',_,',
#   'likewise_RB',
#   '._.'],
#  ['considering_VBG',
#   'all_DT',
#   'things_NNS',
#   ',_,',
#   'one_PRP',
#   'might_MD',
#   'have_VB',
#   'expected_VBN',
#   'keziah_NNP',
#   'herself_PRP',
#   'to_TO',
#   'be_VB',
#   'even_RB',
#   'more_RBR',
#   'dismal_JJ',
#   '._.'],
#  ['but_CC',
#   ',_,',
#   'to_IN',
#   'all_DT',
#   'outward_JJ',
#   'appearances_NNS',
#   ',_,',
#   'she_PRP',
#   'was_VBD',
#   'not_RB',
#   '._.'],
#  ['a_DT',
#   'large_JJ',
#   'portion_NN',
#   'of_IN',
#   'her_PRP$',
#   'thirty_CD',
#   '-_HYPH',
#   'nine_CD',
#   'years_NNS',
#   'of_IN',
#   'life_NN',
#   'had_VBD',
#   'been_VBN',
#   'passed_VBN',
#   'under_IN',
#   'a_DT',
#   'wet_JJ',
#   'blanket_NN',
#   ',_,',
#   'so_RB',
#   'to_TO',
#   'speak_VB',
#   ',_,',
#   'and_CC',
#   'she_PRP',
#   'had_VBD',
#   'not_RB',
#   'permitted_VBN',
#   'the_DT',
#   'depressing_NN',
#   'covering_NN',
#   'to_TO',
#   'shut_VB',
#   'out_RP',
#   'more_JJR',
#   'sunshine_NN',
#   'than_IN',
#   'was_VBD',
#   'absolutely_RB',
#   'necessary_JJ',
#   '._.'],
#  ['she_PRP', 'was_VBD', 'taking_VBG', 'up_RP', 'the_DT', 'carpet_NN', '._.'],
#  ['hammond_NNP',
#   "'s_POS",
#   'ward_NN',
#   ',_,',
#   'who_WP',
#   'had_VBD',
#   'called_VBN',
#   'to_TO',
#   'see_VB',
#   'if_IN',
#   'there_EX',
#   'was_VBD',
#   'anything_NN',
#   'she_PRP',
#   'might_MD',
#   'do_VB',
#   'to_TO',
#   'help_VB',
#   ',_,',
#   'was_VBD',
#   'removing_VBG',
#   'towels_NNS',
#   ',_,',
#   'tablecloths_NNS',
#   ',_,',
#   'and_CC',
#   'the_DT',
#   'like_JJ',
#   'from_IN',
#   'the_DT',
#   'drawers_NNS',
#   'in_IN',
#   'a_DT',
#   'tall_JJ',
#   '"_``',
#   'high_JJ',
#   '-_HYPH',
#   'boy_NN',
#   ',_,',
#   '"_\'\'',
#   'folding_VBG',
#   'them_PRP',
#   'and_CC',
#   'placing_VBG',
#   'them_PRP',
#   'in_IN',
#   'an_DT',
#   'old_JJ',
#   'and_CC',
#   'battered_JJ',
#   'trunk_NN',
#   '._.'],
#  ['the_DT',
#   'pair_NN',
#   'had_VBD',
#   'been_VBN',
#   'discussing_VBG',
#   'the_DT',
#   'subject_NN',
#   'which_WDT',
#   'all_DT',
#   'trumet_NNP',
#   'had_VBD',
#   'discussed_VBN',
#   'for_IN',
#   'three_CD',
#   'weeks_NNS',
#   ',_,',
#   'namely_RB',
#   ',_,',
#   'the_DT',
#   '"_``',
#   'calling_NN',
#   '"_\'\'',
#   'to_IN',
#   'the_DT',
#   'pastorate_NN',
#   'of_IN',
#   'the_DT',
#   '"_``',
#   'regular_JJ',
#   '"_\'\'',
#   'church_NN',
#   'of_IN',
#   'the_DT',
#   'rev._NNP',
#   'john_NNP',
#   'ellery_NNP',
#   ',_,',
#   'the_DT',
#   'young_JJ',
#   'divinity_NN',
#   'student_NN',
#   ',_,',
#   'who_WP',
#   'was_VBD',
#   'to_TO',
#   'take_VB',
#   'the_DT',
#   'place_NN',
#   'of_IN',
#   'old_JJ',
#   'parson_NNP',
#   'langley_NNP',
#   ',_,',
#   'minister_NNP',
#   'in_IN',
#   'the_DT',
#   'parish_NN',
#   'for_IN',
#   'over_IN',
#   'thirty_CD',
#   'years_NNS',
#   '._.'],
#  ['discussion_NN',
#   'in_IN',
#   'the_DT',
#   'village_NN',
#   'had_VBD',
#   'now_RB',
#   'reached_VBN',
#   'a_DT',
#   'critical_JJ',
#   'point_NN',
#   ',_,',
#   'for_IN',
#   'the_DT',
#   'reverend_NNP',
#   'john_NNP',
#   'was_VBD',
#   'expected_VBN',
#   'by_IN',
#   'almost_RB',
#   'any_DT',
#   'coach_NN',
#   '._.'],
#  ['in_IN',
#   'those_DT',
#   'days_NNS',
#   ',_,',
#   'the_DT',
#   'days_NNS',
#   'of_IN',
#   'the_DT',
#   'late_JJ',
#   'fifties_NNS',
#   ',_,',
#   'the_DT',
#   'railroad_NN',
#   'down_RP',
#   'the_DT',
#   'cape_NNP',
#   'extended_VBN',
#   'only_RB',
#   'as_RB',
#   'far_RB',
#   'as_IN',
#   'sandwich_NNP',
#   ';_,',
#   'passengers_NNS',
#   'made_VBD',
#   'the_DT',
#   'rest_NN',
#   'of_IN',
#   'their_PRP$',
#   'journey_NN',
#   'by_IN',
#   'stage_NN',
#   '._.'],
#  ['they_PRP',
#   'say_VBP',
#   'he_PRP',
#   "'s_VBZ",
#   'very_RB',
#   'nice_RB',
#   '-_HYPH',
#   'looking_VBG',
#   ',_,',
#   '"_``',
#   'remarked_VBD',
#   'miss_NNP',
#   'van_NNP',
#   'horne_NNP',
#   'soberly_RB',
#   ',_,',
#   'but_CC',
#   'with_IN',
#   'a_DT',
#   'mischievous_NNP',
#   'glance_NN',
#   'under_IN',
#   'her_PRP$',
#   'dark_JJ',
#   'lashes_NNS',
#   'at_IN',
#   'keziah_NNP',
#   '._.'],
#  ['a_DT',
#   'good_JJ',
#   'many_JJ',
#   'years_NNS',
#   'ago_RB',
#   'i_PRP',
#   'saw_VBD',
#   'a_DT',
#   'theater_NN',
#   'show_VB',
#   'up_RP',
#   'to_IN',
#   'boston_NNP',
#   '._.'],
#  ['well_UH',
#   ',_,',
#   'as_IN',
#   'i_PRP',
#   'started_VBD',
#   'to_TO',
#   'say_VB',
#   ',_,',
#   'one_CD',
#   'of_IN',
#   'the_DT',
#   'leadin_NNP',
#   "'_POS",
#   'folks_NNS',
#   'in_IN',
#   'it_PRP',
#   'was_VBD',
#   'the_DT',
#   'old_NNP',
#   'harry_NNP',
#   'himself_PRP',
#   ',_,',
#   'and_CC',
#   'he_PRP',
#   'was_VBD',
#   'pretty_RB',
#   'good_JJ',
#   '-_HYPH',
#   'lookin_NN',
#   "'_''",
#   '._.'],
#  ['why_WRB',
#   ',_,',
#   'aunt_NNP',
#   'keziah_NNP',
#   '!_.',
#   '"_\'\'',
#   'she_PRP',
#   'exclaimed_VBD',
#   '--_:',
#   'those_DT',
#   'who_WP',
#   'knew_VBD',
#   'keziah_NNP',
#   'coffin_NNP',
#   'best_JJS',
#   'usually_RB',
#   'called_VBD',
#   'her_PRP$',
#   'aunt_NN',
#   ',_,',
#   'though_IN',
#   'real_JJ',
#   'nephews_NNS',
#   'and_CC',
#   'nieces_NNS',
#   'she_PRP',
#   'had_VBD',
#   'none--"why_UH',
#   ',_,',
#   'aunt_NNP',
#   'keziah_NNP',
#   '!_.'],
#  ['drat_NNP', 'this_DT', 'carpet_NN', '!_.'],
#  ['i_PRP',
#   'haul_VBP',
#   'up_RP',
#   'a_DT',
#   'chunk_NN',
#   'of_IN',
#   'the_DT',
#   'cellar_JJ',
#   'floor_NN',
#   'with_IN',
#   'every_DT',
#   'one_CD',
#   '._.'],
#  ['the_DT', 'girl_NN', 'laughed_VBD', 'again_RB', '._.'],
#  ['for_IN',
#   'one_CD',
#   'brought_VBN',
#   'up_RP',
#   ',_,',
#   'since_IN',
#   'her_PRP$',
#   'seventh_JJ',
#   'year_NN',
#   ',_,',
#   'in_IN',
#   'the_DT',
#   'strictest_NN',
#   'of_IN',
#   'come_VB',
#   '-_HYPH',
#   'outer_JJ',
#   'families_NNS',
#   ',_,',
#   'she_PRP',
#   'laughed_VBD',
#   'a_DT',
#   'good_JJ',
#   'deal_NN',
#   '._.'],
#  ['many_JJ',
#   'come_VB',
#   '-_HYPH',
#   'outers_NNP',
#   'considered_VBD',
#   'it_PRP',
#   'wicked_JJ',
#   'to_TO',
#   'laugh_VB',
#   '._.'],
#  ['yet_CC',
#   'grace_NNP',
#   'did_VBD',
#   'it_PRP',
#   ',_,',
#   'and_CC',
#   'hers_PRP',
#   'was_VBD',
#   'a_DT',
#   'laugh_NN',
#   'pleasant_JJ',
#   'to_TO',
#   'hear_VB',
#   'and_CC',
#   'distinctly_RB',
#   'pleasant_JJ',
#   'to_TO',
#   'see_VB',
#   '._.'],
#  ['eben_NNP', 'hammond_NNP', '?_.'],
#  ["cap'n_.",
#   'eben_NNP',
#   "'s_VBZ",
#   'the_DT',
#   'salt_NN',
#   'of_IN',
#   'the_DT',
#   'earth_NN',
#   '._.'],
#  ['still_RB',
#   ',_,',
#   'i_PRP',
#   "'m_VBP",
#   'glad_JJ',
#   'to_TO',
#   'hear_VB',
#   'you_PRP',
#   'say_VB',
#   'it_PRP',
#   '._.'],
#  ['and_CC',
#   'uncle_NN',
#   'says_VBZ',
#   'you_PRP',
#   'are_VBP',
#   'as_RB',
#   'good_JJ',
#   'a_DT',
#   'woman_NN',
#   'as_RB',
#   'ever_RB',
#   'lived_VBD',
#   '._.'],
#  ['see_VB', 'my_PRP$', 'errors_NNS', '!_.'],
#  ['land_NN', 'sakes_NNS', '!_.'],
#  ['her_PRP$',
#   'companion_NN',
#   'put_VBD',
#   'down_RP',
#   'the_DT',
#   'tablecloth_NN',
#   'she_PRP',
#   'was_VBD',
#   'folding_VBG',
#   'and_CC',
#   'looked_VBD',
#   'earnestly_RB',
#   'at_IN',
#   'the_DT',
#   'other_JJ',
#   'woman_NN',
#   '._.'],
#  ['i_PRP', 'know_VBP', '._.'],
#  ['i_PRP',
#   'do_VBP',
#   "n't_RB",
#   'care_VB',
#   'if_IN',
#   'you_PRP',
#   'do_VBP',
#   "n't_RB",
#   'belong_VB',
#   'to_IN',
#   'our_PRP$',
#   'church_NN',
#   '._.'],
#  ['mrs._NNP',
#   'coffin_NNP',
#   'waved_VBD',
#   'the_DT',
#   'hammer_NN',
#   'deprecatingly_RB',
#   '._.'],
#  ['there_RB',
#   '!_.',
#   'there_RB',
#   '!_.',
#   '"_\'\'',
#   'she_PRP',
#   'interrupted_VBD',
#   '._.'],
#  ['fight_VB', ',_,', "'_''", 'instead_RB', '._.'],
#  ['well_UH', '!_.'],
#  ['i_PRP',
#   'wo_MD',
#   "n't_RB",
#   'say_VB',
#   'another_DT',
#   'word_NN',
#   'about_RB',
#   'religion_NN',
#   '._.'],
#  ['let_VB',
#   "'s_PRP",
#   'pick_VB',
#   'the_DT',
#   'new_JJ',
#   'minister_NN',
#   'to_IN',
#   'pieces_NNS',
#   '._.'],
#  ['but_CC',
#   'the_DT',
#   'new_JJ',
#   'minister_NN',
#   'was_VBD',
#   'destined_VBN',
#   'to_TO',
#   'remain_VB',
#   'undissected_JJ',
#   'that_DT',
#   'morning_NN',
#   ',_,',
#   'in_IN',
#   'that_DT',
#   'house_NN',
#   'at_IN',
#   'least_JJS',
#   '._.'],
#  ['aunt_NNP',
#   'keziah_NNP',
#   ',_,',
#   '"_\'\'',
#   'she_PRP',
#   'said_VBD',
#   ',_,',
#   '"_``',
#   'why_WRB',
#   'do_VBP',
#   'you_PRP',
#   'go_VB',
#   'away_RB',
#   '?_.'],
#  ['what_WP', 'makes_VBZ', 'you_PRP', '?_.'],
#  ['long_NNP',
#   "'s_POS",
#   'sol_NNP',
#   'was_VBD',
#   'alive_JJ',
#   'and_CC',
#   'could_MD',
#   'do_VB',
#   'his_PRP$',
#   'cobblin_NN',
#   "'_''",
#   'we_PRP',
#   'managed_VBD',
#   'to_TO',
#   'get_VB',
#   'along_RP',
#   'somehow_RB',
#   '._.'],
#  ['what_WP',
#   'i_PRP',
#   'could_MD',
#   'earn_VB',
#   'sewin_NN',
#   "'_''",
#   'helped_VBD',
#   ',_,',
#   'and_CC',
#   'we_PRP',
#   'lived_VBD',
#   'simple_JJ',
#   '._.'],
#  ['but_CC',
#   'when_WRB',
#   'he_PRP',
#   'was_VBD',
#   'taken_VBN',
#   'down_RP',
#   'and_CC',
#   'died_VBD',
#   ',_,',
#   'the_DT',
#   'doctor_NN',
#   "'s_POS",
#   'bills_NNS',
#   'and_CC',
#   'the_DT',
#   'undertaker_NN',
#   "'s_POS",
#   'used_VBN',
#   'up_RB',
#   'what_WP',
#   'little_JJ',
#   'money_NN',
#   'i_PRP',
#   'had_VBD',
#   'put_VBN',
#   'by_RB',
#   ',_,',
#   'and_CC',
#   'the_DT',
#   'sewin_NN',
#   "'_``",
#   'alone_RB',
#   'would_MD',
#   "n't_RB",
#   'keep_VB',
#   'a_DT',
#   'healthy_JJ',
#   'canary_NN',
#   'in_IN',
#   'bird_NN',
#   'seed_NN',
#   '._.'],
#  ['dear_JJ',
#   'land_NN',
#   'knows_VBZ',
#   'i_PRP',
#   'hate_VBP',
#   'to_TO',
#   'leave_VB',
#   'the_DT',
#   'old_JJ',
#   'house_NN',
#   'i_PRP',
#   "'ve_VB",
#   'lived_VBN',
#   'in_IN',
#   'for_IN',
#   'fourteen_CD',
#   'years_NNS',
#   'and_CC',
#   'the_DT',
#   'town_NN',
#   'i_PRP',
#   'was_VBD',
#   'born_VBN',
#   'in_RP',
#   ',_,',
#   'but_CC',
#   'i_PRP',
#   "'ve_VB",
#   'got_VBN',
#   'to_TO',
#   ',_,',
#   'for_IN',
#   'all_DT',
#   'i_PRP',
#   'see_VBP',
#   '._.'],
#  ['the_DT',
#   'girl_NN',
#   "'s_POS",
#   'dark_JJ',
#   'eyes_NNS',
#   'flashed_VBD',
#   'indignantly_RB',
#   '._.'],
#  ['he_PRP',
#   'ai_VBP',
#   "n't_RB",
#   'turnin_VBD',
#   "'_''",
#   'me_PRP',
#   'out_RP',
#   '._.'],
#  ['he_PRP',
#   'ai_VBP',
#   "n't_RB",
#   'lettin_JJ',
#   "'_''",
#   'houses_NNS',
#   'for_IN',
#   'his_PRP$',
#   'health_NN',
#   'and_CC',
#   'he_PRP',
#   "'ll_MD",
#   'need_VB',
#   'the_DT',
#   'money_NN',
#   'to_TO',
#   'buy_VB',
#   'his_PRP$',
#   'daughter_NN',
#   "'s_POS",
#   'summer_NN',
#   'rigs_NNS',
#   '._.'],
#  ['annabel_NNP',
#   'was_VBD',
#   'the_DT',
#   'only_JJ',
#   'child_NN',
#   'of_IN',
#   'captain_NNP',
#   'elkanah_NNP',
#   'daniels_NNP',
#   ',_,',
#   'who_WP',
#   'owned_VBD',
#   'the_DT',
#   'finest_JJS',
#   'house_NN',
#   'in_IN',
#   'town_NN',
#   '._.'],
#  ['well_UH',
#   ',_,',
#   '"_\'\'',
#   'she_PRP',
#   'said_VBD',
#   ',_,',
#   '"_``',
#   'anyhow_RB',
#   'i_PRP',
#   "'ve_VB",
#   'got_VBN',
#   'to_TO',
#   'go_VB',
#   '._.'],
#  ['maybe_RB',
#   'i_PRP',
#   "'ll_MD",
#   'like_VB',
#   'boston_NNP',
#   'first_JJ',
#   'rate_NN',
#   ',_,',
#   'you_PRP',
#   'ca_MD',
#   "n't_RB",
#   'tell_VB',
#   '._.'],
#  ['or_CC', 'maybe_RB', 'i_PRP', 'wo_MD', "n't_RB", '._.'],
#  ['a_DT', 'proposal_NN', '!_.'],
#  ['sakes_NNP', 'alive_JJ', '!_.'],
#  ['o_UH', 'james_NNP', '!_.'],
#  ['jim_NNP',
#   'said_VBD',
#   'afterwards_RB',
#   'that_IN',
#   'the_DT',
#   'suddenest_JJS',
#   'thing_NN',
#   'about_IN',
#   'it_PRP',
#   'was_VBD',
#   'the_DT',
#   'way_NN',
#   'he_PRP',
#   'cleared_VBD',
#   'out_IN',
#   'of_IN',
#   'that_DT',
#   'house_NN',
#   '._.'],
#  ['i_PRP', "'m_VBP", 'in_IN', 'earnest_JJ', '._.'],
#  ['it_PRP',
#   'seems_VBZ',
#   'to_IN',
#   'me_PRP',
#   'that_IN',
#   'you_PRP',
#   'might_MD',
#   'do_VB',
#   'quite_RB',
#   'well_RB',
#   'at_IN',
#   'dressmaking_VBG',
#   'here_RB',
#   'in_IN',
#   'town_NN',
#   ',_,',
#   'if_IN',
#   'you_PRP',
#   'had_VBD',
#   'a_DT',
#   'little_JJ',
#   '--_:',
#   'well_UH',
#   ',_,',
#   'ready_JJ',
#   'money_NN',
#   'to_TO',
#   'help_VB',
#   'you_PRP',
#   'at_IN',
#   'the_DT',
#   'start_NN',
#   '._.'],
#  ['i_PRP',
#   "'ve_VB",
#   'got_VBN',
#   'a_DT',
#   'few_JJ',
#   'hundred_CD',
#   'dollars_NNS',
#   'in_IN',
#   'the_DT',
#   'bank_NN',
#   ',_,',
#   'presents_VBZ',
#   'from_IN',
#   'uncle_NN',
#   ',_,',
#   'and_CC',
#   'my_PRP$',
#   'father_NN',
#   "'s_POS",
#   'insurance_NN',
#   'money_NN',
#   '._.'],
#  ['the_DT',
#   'negative_JJ',
#   'was_VBD',
#   'so_RB',
#   'decided_VBN',
#   'that_IN',
#   'grace_NNP',
#   'was_VBD',
#   'silenced_VBN',
#   '._.'],
#  ['you_PRP', 'ca_MD', "n't_RB", 'tell_VB', '._.'],
#  ['annabel_NNP',
#   'ai_VBP',
#   "n't_RB",
#   'given_VBN',
#   'up_RP',
#   'hope_NN',
#   'yet_RB',
#   ';_:',
#   'why_WRB',
#   'should_MD',
#   'i_PRP',
#   '?_.'],
#  ['hey_UH', '?_.'],
#  ['her_PRP$',
#   'companion_NN',
#   'sprang_VBD',
#   'to_IN',
#   'her_PRP$',
#   'feet_NNS',
#   'and_CC',
#   'ran_VBD',
#   'to_IN',
#   'the_DT',
#   'window_NN',
#   '._.'],
#  ['he_PRP',
#   'must_MD',
#   'be_VB',
#   'coming_VBG',
#   'to_TO',
#   'see_VB',
#   'you_PRP',
#   ',_,',
#   'aunt_NNP',
#   'keziah_NNP',
#   '._.'],
#  ['and_CC',
#   'he_PRP',
#   "'s_VBZ",
#   'got_VBN',
#   'on_IN',
#   'his_PRP$',
#   'very_RB',
#   'best_JJS',
#   'sunday_NNP',
#   'clothes_NNS',
#   '._.'],
#  ['gracious_JJ', '!_.'],
#  ['i_PRP', 'must_MD', 'be_VB', 'going_VBG', '._.'],
#  ['to_TO',
#   'talk_VB',
#   'about_IN',
#   'the_DT',
#   'minister_NN',
#   ',_,',
#   'i_PRP',
#   "s'pose_VBD",
#   '._.'],
#  ['he_PRP',
#   'was_VBD',
#   'born_VBN',
#   'in_IN',
#   'the_DT',
#   'village_NN',
#   'and_CC',
#   ',_,',
#   'when_WRB',
#   'a_DT',
#   'youngster_NN',
#   ',_,',
#   'had_VBD',
#   ',_,',
#   'like_IN',
#   'every_DT',
#   'other_JJ',
#   'boy_NN',
#   'of_IN',
#   'good_JJ',
#   'family_NN',
#   'in_IN',
#   'the_DT',
#   'community_NN',
#   ',_,',
#   'cherished_VBN',
#   'ambitions_NNS',
#   'for_IN',
#   'a_DT',
#   'seafaring_VBG',
#   'life_NN',
#   '._.'],
#  ['his_PRP$',
#   'sister_NN',
#   ',_,',
#   'lavinia_NNP',
#   ',_,',
#   'ten_CD',
#   'years_NNS',
#   'older_JJR',
#   'than_IN',
#   'he_PRP',
#   ',_,',
#   'who_WP',
#   ',_,',
#   'after_IN',
#   'the_DT',
#   'death_NN',
#   'of_IN',
#   'their_PRP$',
#   'parents_NNS',
#   ',_,',
#   'had_VBD',
#   'undertaken_VBN',
#   'the_DT',
#   'job_NN',
#   'of_IN',
#   '"_``',
#   'bringing_VBG',
#   'up_RP',
#   '"_\'\'',
#   'her_PRP$',
#   'brother_NN',
#   ',_,',
#   'did_VBD',
#   'not_RB',
#   'sympathize_VB',
#   'with_IN',
#   'these_DT',
#   'ambitions_NNS',
#   '._.'],
#  ['consequently_RB',
#   ',_,',
#   'when_WRB',
#   'kyan_NNP',
#   'ran_VBD',
#   'away_RB',
#   'she_PRP',
#   'followed_VBD',
#   'him_PRP',
#   'to_IN',
#   'boston_NNP',
#   ',_,',
#   'stalked_VBN',
#   'aboard_IN',
#   'the_DT',
#   'vessel_NN',
#   'where_WRB',
#   'he_PRP',
#   'had_VBD',
#   'shipped_VBN',
#   ',_,',
#   'and_CC',
#   'collared_VBN',
#   'him_PRP',
#   ',_,',
#   'literally_RB',
#   'and_CC',
#   'figuratively_RB',
#   '._.'],
#  ['one_CD',
#   'of_IN',
#   'the_DT',
#   'mates_NNS',
#   'venturing_VBG',
#   'to_TO',
#   'offer_VB',
#   'objection_NN',
#   ',_,',
#   'lavinia_NNP',
#   'turned_VBD',
#   'upon_IN',
#   'him_PRP',
#   'and_CC',
#   'gave_VBD',
#   'him_PRP',
#   'a_DT',
#   'piece_NN',
#   'of_IN',
#   'her_PRP$',
#   'mind_NN',
#   ',_,',
#   'to_IN',
#   'the_DT',
#   'immense_JJ',
#   'delight_NN',
#   'of_IN',
#   'the_DT',
#   'crew_NN',
#   'and_CC',
#   'the_DT',
#   'loungers_NNS',
#   'on_IN',
#   'the_DT',
#   'wharf_NN',
#   '._.'],
#  ['then_RB',
#   'she_PRP',
#   'returned_VBD',
#   'with_IN',
#   'the_DT',
#   'vagrant_NN',
#   'to_IN',
#   'trumet_NNP',
#   '._.'],
#  ['that_DT',
#   'was_VBD',
#   'kyan_NNP',
#   "'s_POS",
#   'sole_JJ',
#   'venture_NN',
#   ',_,',
#   'so_RB',
#   'far_RB',
#   'as_IN',
#   'sailoring_VBG',
#   'was_VBD',
#   'concerned_VBN',
#   ',_,',
#   'but_CC',
#   'he_PRP',
#   'ran_VBD',
#   'away_RB',
#   'again_RB',
#   'when_WRB',
#   'he_PRP',
#   'was_VBD',
#   'twenty_CD',
#   '-_HYPH',
#   'five_CD',
#   '._.'],
#  ['this_DT',
#   'time_NN',
#   'he_PRP',
#   'returned_VBD',
#   'of_IN',
#   'his_PRP$',
#   'own_JJ',
#   'accord_NN',
#   ',_,',
#   'bringing_VBG',
#   'a_DT',
#   'wife_NN',
#   'with_IN',
#   'him_PRP',
#   ',_,',
#   'one_CD',
#   'evelyn_NNP',
#   'gott_NNP',
#   'of_IN',
#   'ostable_NNP',
#   '._.'],
#  ['evelyn_NNP',
#   'could_MD',
#   'talk_VB',
#   'a_DT',
#   'bit_NN',
#   'herself_PRP',
#   ',_,',
#   'and_CC',
#   'her_PRP$',
#   'first_JJ',
#   'interview_NN',
#   'with_IN',
#   'lavinia_NNP',
#   'ended_VBD',
#   'with_IN',
#   'the_DT',
#   'latter_NN',
#   "'s_POS",
#   'leaving_VBG',
#   'the_DT',
#   'house_NN',
#   'in_IN',
#   'a_DT',
#   'rage_NN',
#   ',_,',
#   'swearing_VBG',
#   'never_RB',
#   'to_TO',
#   'set_VB',
#   'foot_NN',
#   'in_IN',
#   'it_PRP',
#   'again_RB',
#   '._.'],
#  ['this_DT',
#   'oath_NN',
#   'she_PRP',
#   'broke_VBD',
#   'the_DT',
#   'day_NN',
#   'of_IN',
#   'her_PRP$',
#   'sister_NN',
#   '-_HYPH',
#   'in_IN',
#   '-_HYPH',
#   'law_NN',
#   "'s_POS",
#   'funeral_NN',
#   '._.'],
#  ['then_RB',
#   'she_PRP',
#   'appeared_VBD',
#   ',_,',
#   'after_IN',
#   'the_DT',
#   'ceremony_NN',
#   ',_,',
#   'her_PRP$',
#   'baggage_NN',
#   'on_IN',
#   'the_DT',
#   'wagon_NN',
#   'with_IN',
#   'her_PRP',
#   '._.'],
#  ['my_PRP$', 'land_NN', '!_.'],
#  ['laviny_JJ',
#   ',_,',
#   '"_\'\'',
#   'he_PRP',
#   'exclaimed_VBD',
#   ',_,',
#   'turning_VBG',
#   'pale_NN',
#   '._.'],
#  ['you_PRP',
#   'can_MD',
#   'tote_VB',
#   'my_PRP$',
#   'things_NNS',
#   'right_RB',
#   'in_RB',
#   ',_,',
#   '"_\'\'',
#   'she_PRP',
#   'added_VBD',
#   ',_,',
#   'turning_VBG',
#   'to_IN',
#   'her_PRP$',
#   'grinning_VBG',
#   'driver_NN',
#   ',_,',
#   '"_\'\'',
#   'and_CC',
#   'you_PRP',
#   ',_,',
#   "'_''",
#   'bishy_NNP',
#   ',_,',
#   'go_VB',
#   'right_RB',
#   'in_RB',
#   'with_IN',
#   "'em_PRP",
#   '._.'],
#  ['she_PRP',
#   'kept_VBD',
#   'house_NN',
#   'for_IN',
#   'him_PRP',
#   ',_,',
#   'and_CC',
#   'did_VBD',
#   'it_PRP',
#   'well_RB',
#   ',_,',
#   'but_CC',
#   'her_PRP$',
#   'one_CD',
#   'fear_NN',
#   'was_VBD',
#   'that_IN',
#   'some_DT',
#   'female_JJ',
#   'might_MD',
#   'again_RB',
#   'capture_VB',
#   'him_PRP',
#   ',_,',
#   'and_CC',
#   'she_PRP',
#   'watched_VBD',
#   'him_PRP',
#   'with_IN',
#   'an_DT',
#   'eagle_NN',
#   'eye_NN',
#   '._.'],
#  ['he_PRP',
#   "'s_VBZ",
#   'dressed_JJ',
#   'to_TO',
#   'kill_VB',
#   ',_,',
#   '"_\'\'',
#   'whispered_VBD',
#   'grace_NNP',
#   ',_,',
#   'at_IN',
#   'the_DT',
#   'window_NN',
#   '._.'],
#  ['even_RB',
#   'his_PRP$',
#   'tall_JJ',
#   'hat_NN',
#   ';_:',
#   'and_CC',
#   'in_IN',
#   'this_DT',
#   'fog_NN',
#   '!_.'],
#  ['laviny_NNP',
#   'put_VBD',
#   'him_PRP',
#   'up_RP',
#   'to_IN',
#   'it_PRP',
#   ',_,',
#   'you_PRP',
#   'see_VBP',
#   '._.'],
#  ['she_PRP', "'ll_MD", 'be_VB', 'along_RB', 'pretty_RB', 'quick_JJ', '._.'],
#  ['well_UH',
#   ',_,',
#   'i_PRP',
#   "'ll_MD",
#   'fix_VB',
#   'him_PRP',
#   'so_IN',
#   'he_PRP',
#   'wo_MD',
#   "n't_RB",
#   'talk_VB',
#   'much_RB',
#   '._.'],
#  ['he_PRP',
#   'can_MD',
#   'help_VB',
#   'us_PRP',
#   'take_VB',
#   'down_IN',
#   'that_DT',
#   'stovepipe_NN',
#   '._.'],
#  ['come_VB', 'right_RB', 'in_RB', '._.'],
#  ['yes_UH', ',_,', 'yes_UH', '._.'],
#  ['glad_JJ', 'to_TO', 'see_VB', 'you_PRP', '._.'],
#  ['take_VB', 'off_RP', 'your_PRP$', 'hat_NN', '._.']]

# %%
 with open('gutenberg_sentences_with_tags.txt', 'w') as f:
    for sent in tokenized_sentences:
        if len(sent)>0:
            f.write(" ".join(sent)+"\n" )

# %% [markdown]
# ### Amazon data

# %%
import random
random.seed(3010010)

# %%
import spacy
nlp = spacy.load("en")

# %%
from tqdm import tqdm
import json

# %%
urls = [
    '/Volumes/extra_data/reviews_Beauty_5.json.gz',
    '/Volumes/extra_data/reviews_Home_and_Kitchen_5.json.gz',
    '/Volumes/extra_data/reviews_Grocery_and_Gourmet_Food_5.json.gz',
    '/Volumes/extra_data/reviews_Sports_and_Outdoors_5.json.gz',
]

# %%
import gzip
def parse(path): 
    g = gzip.open(path, 'r') 
    for l in g: 
        yield eval(l)

# %%
from collections import defaultdict

# %%
tokenized_sentences_amazon = []
item2count = defaultdict(int)
# token2pos_tag_counts_amazon = defaultdict(lambda: defaultdict(int))

for url in tqdm(urls):
    c=0
    x = parse(url)
    #for i in tqdm(x):
    for i in x:
#         item = i['asin']
#         if item2count[item]>7: ## max per item
#             pass
#         else:
        review = nlp(i['reviewText'])
        try:
            sents = list(review.sents)
            sents_ok = [sent for sent in sents if (sent.text[0] in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ' and sent.text[-1] in ".?!")]
            sent = random.choice(sents_ok)
            tagged = [(i.text.lower(),i.tag_) for i in sent]
            tagged_clean = [(token,tag) for token,tag in tagged if "\n" not in token]
            tokens = [token+"_"+tag for token,tag in tagged_clean]
            tokenized_sentences_amazon.append(tokens)
#             for token,tag in tagged_clean:
#                 token2pos_tag_counts_amazon[token][tag]+=1
            c+=1
            #item2count[item]+=1
        except:
            pass
#         if c>50: ## max number for debugging
#             print("break!")
#             break
# Out:
# 100%|██████████| 4/4 [6:06:13<00:00, 5493.38s/it]

# %%
len(tokenized_sentences_amazon)
# Out:
# 1087605

# %%
tokenized_sentences_amazon[:10]
# Out:
# [['very_RB', 'oily_JJ', 'and_CC', 'creamy_JJ', '._.'],
#  ['this_DT',
#   'palette_NN',
#   'conceals_NNS',
#   'decently_RB',
#   ',_,',
#   'however_RB',
#   ',_,',
#   'it_PRP',
#   'does_VBZ',
#   'somewhat_RB',
#   'cake_VB',
#   'up_RP',
#   'and_CC',
#   'crease_VB',
#   '._.'],
#  ['and_CC',
#   'so_RB',
#   'far_RB',
#   'i_PRP',
#   'tried_VBD',
#   'twice_RB',
#   'but_CC',
#   'it_PRP',
#   'does_VBZ',
#   'nt_RB',
#   'really_RB',
#   'show_VB',
#   'any_DT',
#   'color_NN',
#   'on_IN',
#   'my_PRP$',
#   'face_NN',
#   '._.'],
#  ['i_PRP',
#   'think_VBP',
#   'it_PRP',
#   'does_VBZ',
#   'great_JJ',
#   'coverage_NN',
#   'for_IN',
#   'the_DT',
#   'price_NN',
#   'i_PRP',
#   'paid_VBD',
#   '._.'],
#  ['i_PRP',
#   'also_RB',
#   'use_VBP',
#   'a_DT',
#   'silicone_NN',
#   'based_VBN',
#   'primer_NNP',
#   ',_,',
#   'which_WDT',
#   'works_VBZ',
#   'well_RB',
#   'for_IN',
#   'my_PRP$',
#   'skin_NN',
#   'type_NN',
#   'to_TO',
#   'give_VB',
#   'me_PRP',
#   'the_DT',
#   'fresh_JJ',
#   ',_,',
#   'dewy_JJ',
#   'look_NN',
#   'i_PRP',
#   'love_VBP',
#   '._.'],
#  ['do_VB', 'it_PRP', '!_.'],
#  ['i_PRP', 'would_MD', 'not_RB', 'recommend_VB', '._.'],
#  ['stings_NNS', 'when_WRB', 'i_PRP', 'put_VBD', 'it_PRP', 'on_RP', '._.'],
#  ['i_PRP',
#   'bought_VBD',
#   'this_DT',
#   'product_NN',
#   'to_TO',
#   'get_VB',
#   'rid_VBN',
#   'of_IN',
#   'the_DT',
#   'dark_JJ',
#   'spots_NNS',
#   'i_PRP',
#   'had_VBD',
#   'on_IN',
#   'my_PRP$',
#   'face_NN',
#   'due_IN',
#   'to_IN',
#   'acne_NNP',
#   'scars_NNS',
#   'and_CC',
#   'it_PRP',
#   'did_VBD',
#   'help_VB',
#   'a_DT',
#   'bit_NN',
#   '._.'],
#  ['it_PRP',
#   'actually_RB',
#   'started_VBD',
#   'to_TO',
#   'literally_RB',
#   'peel_VB',
#   'the_DT',
#   'dark_JJ',
#   'skin_NN',
#   'away_RB',
#   '._.']]

# %%
 with open('amazon_sentences_with_tags.txt', 'w') as f:
    for sent in tokenized_sentences_amazon:
        if len(sent)>0:
            f.write(" ".join(sent)+"\n" )

# %% [markdown]
# ## Combine

# %% [markdown]
# ### Combine tokenized sents and shuffle

# %%
import random
random.seed(2091848572)

# %%
with open('amazon_sentences_with_tags.txt','r') as f:
    amz = f.readlines()
    
with open('gutenberg_sentences_with_tags.txt','r') as f:
    gtb = f.readlines()

# %%
len(amz)
# Out:
# 1087605

# %%
len(gtb)
# Out:
# 4850043

# %%
combined = amz + gtb

# %%
random.shuffle(combined)

# %%
with open('gutenberg_and_amazon_sents_with_tags_tokenized_shuffled.txt','w') as f:
    for sent in combined:
        if len(sent)>0:
            f.write(sent)

# %% [markdown]
# Small version for convenience when debugging model.

# %%
with open('gutenberg_and_amazon_sents_with_tags_tokenized_shuffled_2000_sents.txt','w') as f:
    for sent in combined[:2000]:
        if len(sent)>0:
            f.write(sent)

# %%
combined[:10]
# Out:
# ['something_NN had_VBD obliged_VBN her_PRP to_TO tell_VB her_PRP ._.\n',
#  "he_PRP had_VBD struck_VBN at_IN me_PRP with_IN his_PRP$ automatic_NN ,_, which_WDT i_PRP think_VBP he_PRP must_MD have_VB dropped_VBN ,_, though_RB i_PRP 'm_VBP not_RB sure_JJ of_IN that_DT ._.\n",
#  'being_VBG a_DT type_NN 2_CD diabetic_NN ,_, i_PRP am_VBP always_RB looking_VBG sweet_JJ tasting_NN treats_NNS that_WDT will_MD not_RB affect_VB my_PRP$ blood_NN sugar_NN and_CC this_DT sugarfree_JJ gum_NN is_VBZ now_RB very_RB high_JJ on_IN my_PRP$ list_NN favorite_JJ things_NNS ._.\n',
#  'it_PRP happened_VBD thus_RB ._.\n',
#  'secondly_RB ,_, jim_NNP had_VBD gone_VBN to_IN heaps_NNS of_IN trouble_NN gathering_VBG all_PDT the_DT breeding_NN -_HYPH stock_NN of_IN holy_NNP cross_NNP ,_, for_IN a_DT party_NN named_VBN jabez_NNP y._NNP stone_NNP to_TO steal_VB them_PRP convenient_RB ._.\n',
#  'he_PRP had_VBD been_VBN taunted_VBN about_IN it_PRP --_: by_IN boys_NNS ._.\n',
#  'he_PRP is_VBZ exchanged_VBN at_IN length_NN ,_, but_CC before_IN leaving_VBG he_PRP brings_VBZ one_CD james_NNP molesworth_NNP to_IN the_DT house_NN ,_, claiming_VBG that_IN he_PRP does_VBZ not_RB like_VB to_TO leave_VB them_PRP unprotected_JJ ._.\n',
#  'it_PRP works_VBZ again_RB ._.\n',
#  "after_IN this_DT ,_, his_PRP$ parents_NNS let_VBP him_PRP join_VB the_DT telegraphers_NNPS '_POS battalion_NNP no_NN ._NN 3_CD ,_, at_IN koblenz_NNP ,_, as_IN color_NN guard_NN ._.\n",
#  'permit_NN me_PRP to_TO renew_VB through_IN you_PRP the_DT expression_NN of_IN sorrow_NN and_CC sympathy_NN which_WDT i_PRP have_VBP already_RB telegraphed_VBN to_IN attorney_NNP -_HYPH general_NNP macveagh_NNP ._.\n']

# %% [markdown]
# ## Count Tokens

# %%
from collections import defaultdict

word2count = defaultdict(int)

for s in combined:
    for t in s.split():
        word2count[t.lower()]+=1

# %%
word2count['sugarfree_jj']
# Out:
# 0

# %%
len(word2count.keys())
# Out:
# 750552

# %%
to_delete = []

for w in word2count:
    if word2count[w]<5: ## min count of word2vec model
        to_delete.append(w)
        
for wd in to_delete:
    del word2count[wd]

# %%
word2count['sugarfree_jj']
# Out:
# 0

# %%
len(word2count.keys())
# Out:
# 180394

# %%
import json
with open('gutenberg_and_amazon_token2count.json','w') as f:
    json.dump(word2count,f)

# %% [markdown]
# ***
